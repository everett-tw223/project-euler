# %% [markdown]
# Problem 39 - Integer Right Triangles
#
#
# If p is the perimeter of a right angle triangle with integral length sides, {a,b,c}, there are exactly three solutions for p = 120.
#
# {20,48,52}, {24,45,51}, {30,40,50}
#
# For which value of p ≤ 1000, is the number of solutions maximised?

# %%
import math
import numpy as np
from numpy import linalg
import time
from collections import deque, Counter
from itertools import permutations, combinations
import statistics

# %% [markdown]
# a^2 + b^2 = c^2
#
# p = a + b + c

# %%
for i in range(1,1001):

# %%
math.sqrt(500)
# Out:
# 22.360679774997898

# %%
squares_list = []
for i in range(1,23):
    squares_list+=[i**2]
#print(squares_list)
print(squares_list)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484]

# %%
i = 0
perimeter = 14
while perimeter <=500:
    perimeter = squares_list[i]+squares_list[i+1]
    i+=1
print(i)
# Out:
# 16

# %%
squares_list[16]
# Out:
# 289

# %%
squares_list_2 = squares_list[:17]
print(squares_list_2)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289]

# %%
object_1 = combinations(squares_list,3)
comb_list = []
for element in list(object_1):
    comb_list+=[element]
print(comb_list)
print(len(comb_list))
# Out:
# [(1, 4, 9), (1, 4, 16), (1, 4, 25), (1, 4, 36), (1, 4, 49), (1, 4, 64), (1, 4, 81), (1, 4, 100), (1, 4, 121), (1, 4, 144), (1, 4, 169), (1, 4, 196), (1, 4, 225), (1, 4, 256), (1, 4, 289), (1, 4, 324), (1, 4, 361), (1, 4, 400), (1, 4, 441), (1, 4, 484), (1, 4, 529), (1, 4, 576), (1, 4, 625), (1, 4, 676), (1, 4, 729), (1, 4, 784), (1, 4, 841), (1, 4, 900), (1, 4, 961), (1, 9, 16), (1, 9, 25), (1, 9, 36), (1, 9, 49), (1, 9, 64), (1, 9, 81), (1, 9, 100), (1, 9, 121), (1, 9, 144), (1, 9, 169), (1, 9, 196), (1, 9, 225), (1, 9, 256), (1, 9, 289), (1, 9, 324), (1, 9, 361), (1, 9, 400), (1, 9, 441), (1, 9, 484), (1, 9, 529), (1, 9, 576), (1, 9, 625), (1, 9, 676), (1, 9, 729), (1, 9, 784), (1, 9, 841), (1, 9, 900), (1, 9, 961), (1, 16, 25), (1, 16, 36), (1, 16, 49), (1, 16, 64), (1, 16, 81), (1, 16, 100), (1, 16, 121), (1, 16, 144), (1, 16, 169), (1, 16, 196), (1, 16, 225), (1, 16, 256), (1, 16, 289), (1, 16, 324), (1, 16, 361), (1, 16, 400), (1, 16, 441), (1, 16, 484), (1, 16, 529), (1, 16, 5
# ...

# %%
peri_sums = []
for triple in comb_list:
    peri_sums+=[sum(triple)]
#print(len(peri_sums))
#print("Mode of given data set is % s" % (statistics.multimode(peri_sums)))
#print(max(set(peri_sums), key=peri_sums.count))

# %%
data = Counter(peri_sums)
print(data.most_common(3))  # Returns all unique items and their counts
#data.most_common(1)
# Out:
# [(854, 11), (941, 11), (734, 10)]

# %%
print(len(peri_sums))
# Out:
# 4495

# %%
test_comb = combinations([1,2,3],2)
list_1 = []
for element in list(test_comb):
    print(element)
    list_1+=[element]
print(list_1)
# Out:
# (1, 2)
# (1, 3)
# (2, 3)
# [(1, 2), (1, 3), (2, 3)]

# %%
print(combinations([1,2,3],2))
